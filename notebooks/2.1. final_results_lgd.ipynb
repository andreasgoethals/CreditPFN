# %% [markdown]
# # Final results — LGD
#
# Every trained CreditPFN checkpoint, every classical baseline,
# and every untuned-TabPFN reference, scored on every held-out
# test dataset with 5-fold cross-validation. The visualisations
# here are the canonical "how did we do" view — used both for
# thesis figures and for picking the headline checkpoint to
# report.
#
# ## Where the data comes from
#
# `scripts/eval_pipeline.py` writes one wide-format CSV per
# (method × run × timestamp) under
# `output/results/<TRACK>/<method-dirname>/...csv`.
#
# Each row is one `(model × test_dataset × fold)` tuple with all
# metric columns side-by-side:
#
# * **PD (classification)** — `roc_auc, log_loss, pr_auc,
#   optimal_threshold, f1, accuracy, precision, recall`.
# * **LGD (regression)** — `rmse, mae, r2, neg_nll`.
#
# Method directory names encode the architecture, and
# `src/utils/eval_viz._decode_method_dirname` parses them into
# structured `(source, base_short, lr, use_lora)` fields. The
# human-readable label used in legends is built by
# `human_method_name()`.
#
# All loaders and plots live in `src/utils/eval_viz.py`;
# this notebook only calls them.
#
# ## Direction of improvement
#
# Higher-is-better metrics: `roc_auc`, `pr_auc`, `f1`, `accuracy`,
# `precision`, `recall`, `r2`, `neg_nll`.
# Lower-is-better: `rmse`, `mae`, `log_loss`. Every aggregation /
# ranking helper is direction-aware.
#
# ## Sections
#
# 1. Setup and what's on disk
# 2. Headline leaderboard
# 3. Per-dataset performance
# 4. Pairwise comparisons (win-rate matrix, scatter)
# 5. Trained vs untuned TabPFN (the Real-TabPFN-style "did it help?" plot)
# 6. Stability and calibration
# 7. Time vs accuracy
# 8. Failures

# %%
# %matplotlib inline
import sys, os
from pathlib import Path
REPO = Path(os.getcwd()).resolve()
# pyproject.toml, not a module path: src/visualize/ used to be
# src/utils/ and this loop then walked past the repo root.
while not (REPO / 'pyproject.toml').exists() and REPO.parent != REPO:
    REPO = REPO.parent
sys.path.insert(0, str(REPO))

# `display` is an IPython builtin. src/utils/run_notebooks.py executes this file as
# a plain script to rebuild All_Results.md, where it is not — so import it.
from IPython.display import display

import pandas as pd
from src.visualize.figures import FigureSaver
from src.visualize import style
from src.visualize.eval_viz import (
    load_eval_results, available_methods, available_datasets,
    primary_metric, eval_leaderboard, failed_pairs,
    aggregate_per_method, aggregate_per_method_per_dataset, winrate_matrix,
    plot_leaderboard, plot_metric_boxplot, plot_per_dataset_heatmap,
    plot_winrate_matrix, plot_method_vs_method_scatter,
    plot_trained_vs_untuned, plot_baselines_vs_tabpfn,
    plot_fold_stability, plot_metric_correlation,
    plot_threshold_distribution, plot_top_method_per_dataset,
    plot_dataset_difficulty, plot_time_vs_metric,
)
pd.set_option('display.width', 160)
pd.set_option('display.max_columns', 40)
TRACK = 'lgd'    # this notebook is fixed to the LGD track
sink = FigureSaver('2.1. final_results_lgd')

# One style for every figure in this project.
style.apply()

# %% [markdown]
# ## 1 · What's on disk
#
# `load_eval_results` pools every CSV under
# `output/results/<TRACK>/**/*.csv` and tags each row with
# `(source, base_short, lr, use_lora, method_name, source_file)`
# derived from the parent directory name.
#
# If the tables below are empty, the eval pipeline hasn't produced
# any CSVs yet for this track — the notebook will still render but
# every plot will show a *(no data)* stub.

# %%
print(f'Primary metric for track={TRACK}: {primary_metric(TRACK)}')
print(f'Methods on disk : {len(available_methods(TRACK))}')
print(f'Test datasets   : {len(available_datasets(TRACK))}')
available_methods(TRACK)
# Out:
# Primary metric for track=lgd: rmse
# Methods on disk : 22
# Test datasets   : 2
# ['catboost',
#  'linreg',
#  'trained (tabicl-v2) lr=1e-06',
#  'trained (tabicl-v2) lr=1e-06 ·ICLhead',
#  'trained (tabicl-v2) lr=1e-06 ·ICLhead ·min5k',
#  'trained (tabicl-v2) lr=1e-06 ·min5k',
#  'trained (tabicl-v2) lr=3e-07',
#  'trained (tabicl-v2) lr=3e-07 ·ICLhead',
#  'trained (tabicl-v2) lr=3e-07 ·ICLhead ·min5k',
#  'trained (tabicl-v2) lr=3e-07 ·min5k',
#  'trained (v2.6-default) lr=1e-06',
#  'trained (v2.6-default) lr=1e-06 ·min5k',
#  'trained (v2.6-default) lr=3e-07',
#  'trained (v2.6-default) lr=3e-07 ·min5k',
#  'trained (v3-default) lr=1e-06',
#  'trained (v3-default) lr=1e-06 ·min5k',
#  'trained (v3-default) lr=3e-07',
#  'trained (v3-default) lr=3e-07 ·min5k',
#  'untuned (tabicl-v2)',
#  'untuned (v2.6-default)',
#  'untuned (v3-default)',
#  'xgboost']

# %%
raw = load_eval_results(TRACK)
print(f'rows: {len(raw)}')
if not raw.empty:
    display(raw.head(10))
# Out:
# rows: 220
#   track   task_type model_name model_source model_path       test_dataset_id  fold_idx  n_train_rows  n_val_rows  n_test_rows  roc_auc  log_loss  pr_auc  \
# 0   lgd  regression   catboost     baseline        NaN            0002.loss2         0          2967         742          928      NaN       NaN     NaN
# 1   lgd  regression   catboost     baseline        NaN            0002.loss2         1          2967         742          928      NaN       NaN     NaN
# 2   lgd  regression   catboost     baseline        NaN            0002.loss2         2          2968         742          927      NaN       NaN     NaN
# 3   lgd  regression   catboost     baseline        NaN            0002.loss2         3          2968         742          927      NaN       NaN     NaN
# 4   lgd  regression   catboost     baseline        NaN            0002.loss2         4          2968         742          927      NaN       NaN     NaN
# 5   lgd  regression   catboost     baseline        NaN  0007.lgd_lendingclub         0          3600         901         1126      NaN       NaN     NaN
# 6   lgd  regression   catboost     baseline        NaN  0007.lgd_lendingclub         1          3600         901         1126      NaN       NaN     NaN
# 7   lgd  regression   catboost     baseline        NaN  0007.lgd_lendingclub         2          3601         901         1125      NaN       NaN     NaN
# 8   lgd  regression   catboost     baseline        NaN  0007.lgd_lendingclub         3          3601         901         1125      NaN       NaN     NaN
# 9   lgd  regression   catboost     baseline        NaN  0007.lgd_lendingclub         4          3601         901         1125      NaN       NaN     NaN
#
#    brier_score  ece  ece_platt  brier_score_platt  log_loss_platt  ece_isotonic  brier_score_isotonic  ...  mape        r2  explained_variance  pearson_r  \
# 0          NaN  NaN        NaN                NaN             NaN           NaN                   NaN  ...   NaN  0.706906            0.707298   0.841231
# 1          NaN  NaN        NaN                NaN             NaN           NaN                   NaN  ...   NaN  0.646520            0.646816   0.804507
# 2          NaN  NaN        NaN                NaN             NaN           NaN                   NaN  ...   NaN  0.686087            0.686096   0.829691
# 3          NaN  NaN        NaN                NaN             NaN           NaN                   NaN  ...   NaN  0.663600            0.664075   0.816729
# 4          NaN  NaN        NaN                NaN             NaN           NaN                   NaN  ...   NaN  0.669257            0.669339   0.818784
# 5          NaN  NaN        NaN                NaN             NaN           NaN                   NaN  ...   NaN  0.734462            0.734613   0.857217
# 6          NaN  NaN        NaN                NaN             NaN           NaN                   NaN  ...   NaN  0.776018            0.776031   0.881098
# 7          NaN  NaN        NaN                NaN             NaN           NaN                   NaN  ...   NaN  0.734401            0.734643   0.857120
# 8          NaN  NaN        NaN                NaN             NaN           NaN                   NaN  ...   NaN  0.794482            0.794482   0.892206
# 9          NaN  NaN        NaN                NaN             NaN           NaN                   NaN  ...   NaN  0.749646            0.749663   0.865847
#
#    spearman_r  neg_nll  elapsed_sec        timestamp  status  error  method_dirname    source  base_short  lr  use_lora  full_pass  min_train_rows     family  \
# 0    0.825038      NaN   394.495606  20260813_223841      OK    NaN        catboost  baseline    catboost NaN     False      False               0  classical
# 1    0.795843      NaN   450.974838  20260813_223841      OK    NaN        catboost  baseline    catboost NaN     False      False               0  classical
# 2    0.824706      NaN   474.533998  20260813_223841      OK    NaN        catboost  baseline    catboost NaN     False      False               0  classical
# 3    0.798848      NaN   410.928591  20260813_223841      OK    NaN        catboost  baseline    catboost NaN     False      False               0  classical
# 4    0.815607      NaN   400.604422  20260813_223841      OK    NaN        catboost  baseline    catboost NaN     False      False               0  classical
# 5    0.881332      NaN   207.405833  20260816_000303      OK    NaN        catboost  baseline    catboost NaN     False      False               0  classical
# 6    0.895448      NaN   247.699439  20260816_000303      OK    NaN        catboost  baseline    catboost NaN     False      False               0  classical
# 7    0.884829      NaN   285.263597  20260816_000303      OK    NaN        catboost  baseline    catboost NaN     False      False               0  classical
# 8    0.910683      NaN   196.904115  20260816_000303      OK    NaN        catboost  baseline    catboost NaN     False      False               0  classical
# 9    0.885911      NaN   306.157229  20260816_000303      OK    NaN        catboost  baseline    catboost NaN     False      False               0  classical
#
#                                          source_file  method_name
# 0  LGD\catboost\creditpfn_20260813_223841__task4_...     catboost
# 1  LGD\catboost\creditpfn_20260813_223841__task4_...     catboost
# 2  LGD\catboost\creditpfn_20260813_223841__task4_...     catboost
# 3  LGD\catboost\creditpfn_20260813_223841__task4_...     catboost
# 4  LGD\catboost\creditpfn_20260813_223841__task4_...     catboost
# 5  LGD\catboost\creditpfn_20260816_000303__task1_...     catboost
# 6  LGD\catboost\creditpfn_20260816_000303__task1_...     catboost
# 7  LGD\catboost\creditpfn_20260816_000303__task1_...     catboost
# 8  LGD\catboost\creditpfn_20260816_000303__task1_...     catboost
# 9  LGD\catboost\creditpfn_20260816_000303__task1_...     catboost
#
# [10 rows x 53 columns]

# %% [markdown]
# ## 2 · Headline leaderboard
#
# Mean ± std of the primary metric (`roc_auc` for PD, `rmse` for
# LGD) pooled over all `(dataset × fold)` rows of each method.
# Sorted direction-aware so the best method is always at the top.

# %%
eval_leaderboard(TRACK)
# Out:
#                                      method_name      mean    median       std  count
# 0                           untuned (v3-default)  0.132598  0.132131  0.010553     10
# 1                            untuned (tabicl-v2)  0.133726  0.132262  0.011231     10
# 2          trained (tabicl-v2) lr=3e-07 ·ICLhead  0.133875  0.132186  0.011412     10
# 3                   trained (tabicl-v2) lr=3e-07  0.133920  0.132320  0.011507     10
# 4          trained (tabicl-v2) lr=1e-06 ·ICLhead  0.134161  0.132562  0.011623     10
# 5   trained (tabicl-v2) lr=3e-07 ·ICLhead ·min5k  0.134176  0.132604  0.011560     10
# 6                         untuned (v2.6-default)  0.134217  0.132416  0.011743     10
# 7            trained (tabicl-v2) lr=3e-07 ·min5k  0.134360  0.132898  0.011793     10
# 8            trained (tabicl-v2) lr=1e-06 ·min5k  0.134471  0.132837  0.011943     10
# 9                   trained (tabicl-v2) lr=1e-06  0.134505  0.132537  0.012058     10
# 10          trained (v3-default) lr=3e-07 ·min5k  0.134547  0.132864  0.011868     10
# 11  trained (tabicl-v2) lr=1e-06 ·ICLhead ·min5k  0.134548  0.133058  0.011904     10
# 12                 trained (v3-default) lr=3e-07  0.134909  0.133578  0.011053     10
# 13          trained (v3-default) lr=1e-06 ·min5k  0.136816  0.135711  0.013232     10
# 14                 trained (v3-default) lr=1e-06  0.138386  0.137532  0.012349     10
# 15        trained (v2.6-default) lr=3e-07 ·min5k  0.140718  0.138982  0.011508     10
# 16                                      catboost  0.140773  0.138621  0.016384     10
# 17                                       xgboost  0.141341  0.140866  0.016453     10
# 18        trained (v2.6-default) lr=1e-06 ·min5k  0.144703  0.142710  0.010195     10
# 19               trained (v2.6-default) lr=3e-07  0.147545  0.144927  0.009777     10
# 20               trained (v2.6-default) lr=1e-06  0.150148  0.147371  0.010038     10
# 21                                        linreg  0.198255  0.182885  0.074091     10

# %%
sink.save(plot_leaderboard(TRACK), 'leaderboard',
          caption="Mean primary metric per method over all held-out datasets and cross-validation folds, sorted, with one standard deviation as error bars.")

# %%
sink.save(plot_metric_boxplot(TRACK), 'metric_boxplot',
          caption="Distribution of the primary metric per method over all (dataset, fold) cells.")

# %%
sink.save(plot_baselines_vs_tabpfn(TRACK), 'baselines_vs_tabpfn',
          caption="Distribution of the primary metric for the classical baselines and for the foundation-model family, side by side, over all (dataset, fold) cells.")

# %% [markdown]
# ## 3 · Per-dataset performance
#
# Each row of the heatmap is a method, each column a held-out test
# dataset, each cell the mean of the primary metric over the
# 5-fold CV. The bottom plot "who wins on which dataset?" colours
# each dataset by its best-performing method — a fast diagnostic
# for finding datasets where the trained checkpoint isn't paying
# off.

# %%
sink.save(plot_per_dataset_heatmap(TRACK), 'per_dataset_heatmap',
          caption="Mean primary metric for every method on every held-out dataset, averaged over folds.")

# %%
aggregate_per_method_per_dataset(TRACK).round(3)
# Out:
# test_dataset_id                               0002.loss2  0007.lgd_lendingclub
# method_name
# catboost                                           0.155                 0.127
# linreg                                             0.253                 0.143
# trained (tabicl-v2) lr=1e-06                       0.144                 0.125
# trained (tabicl-v2) lr=1e-06 ·ICLhead              0.143                 0.125
# trained (tabicl-v2) lr=1e-06 ·ICLhead ·min5k       0.143                 0.126
# trained (tabicl-v2) lr=1e-06 ·min5k                0.143                 0.125
# trained (tabicl-v2) lr=3e-07                       0.142                 0.125
# trained (tabicl-v2) lr=3e-07 ·ICLhead              0.142                 0.125
# trained (tabicl-v2) lr=3e-07 ·ICLhead ·min5k       0.143                 0.126
# trained (tabicl-v2) lr=3e-07 ·min5k                0.143                 0.125
# trained (v2.6-default) lr=1e-06                    0.158                 0.142
# trained (v2.6-default) lr=1e-06 ·min5k             0.153                 0.136
# trained (v2.6-default) lr=3e-07                    0.155                 0.140
# trained (v2.6-default) lr=3e-07 ·min5k             0.150                 0.131
# trained (v3-default) lr=1e-06                      0.148                 0.129
# trained (v3-default) lr=1e-06 ·min5k               0.147                 0.126
# trained (v3-default) lr=3e-07                      0.143                 0.127
# trained (v3-default) lr=3e-07 ·min5k               0.144                 0.126
# untuned (tabicl-v2)                                0.142                 0.125
# untuned (v2.6-default)                             0.143                 0.126
# untuned (v3-default)                               0.140                 0.125
# xgboost                                            0.155                 0.127

# %%
sink.save(plot_top_method_per_dataset(TRACK), 'top_method_per_dataset',
          caption="The best-scoring method on each held-out dataset, one bar per dataset.")

# %%
sink.save(plot_dataset_difficulty(TRACK), 'dataset_difficulty',
          caption="Best and worst primary metric achieved on each held-out dataset, ordered by the best score.")

# %% [markdown]
# ## 4 · Pairwise comparisons
#
# The **win-rate matrix** counts, for each ordered pair of methods
# (`row` vs `column`), the fraction of test datasets where `row`
# beat `column` (direction-aware). It is the same plot type as
# Fig. 3 of the [TabPFN-3 technical report](../tfm-library/papers/2026/05_Grinsztajn_et_al._TabPFN_3_Technical_Report.pdf) —
# a fast way to see which method dominates which.
#
# The **method-vs-method scatter** lets you pick any two methods
# and view their per-dataset scores side by side; points above
# the y = x line favour the y-axis method.

# %%
winrate_matrix(TRACK).round(2)
# Out:
#                                               catboost  linreg  trained (tabicl-v2) lr=1e-06  trained (tabicl-v2) lr=1e-06 ·ICLhead  \
# catboost                                           NaN     1.0                           0.0                                    0.0
# linreg                                             0.0     NaN                           0.0                                    0.0
# trained (tabicl-v2) lr=1e-06                       1.0     1.0                           NaN                                    0.0
# trained (tabicl-v2) lr=1e-06 ·ICLhead              1.0     1.0                           1.0                                    NaN
# trained (tabicl-v2) lr=1e-06 ·ICLhead ·min5k       1.0     1.0                           0.5                                    0.0
# trained (tabicl-v2) lr=1e-06 ·min5k                1.0     1.0                           0.5                                    0.0
# trained (tabicl-v2) lr=3e-07                       1.0     1.0                           1.0                                    1.0
# trained (tabicl-v2) lr=3e-07 ·ICLhead              1.0     1.0                           1.0                                    1.0
# trained (tabicl-v2) lr=3e-07 ·ICLhead ·min5k       1.0     1.0                           0.5                                    0.5
# trained (tabicl-v2) lr=3e-07 ·min5k                1.0     1.0                           0.5                                    0.0
# trained (v2.6-default) lr=1e-06                    0.0     1.0                           0.0                                    0.0
# trained (v2.6-default) lr=1e-06 ·min5k             0.5     1.0                           0.0                                    0.0
# trained (v2.6-default) lr=3e-07                    0.0     1.0                           0.0                                    0.0
# trained (v2.6-default) lr=3e-07 ·min5k             0.5     1.0                           0.0                                    0.0
# trained (v3-default) lr=1e-06                      0.5     1.0                           0.0                                    0.0
# trained (v3-default) lr=1e-06 ·min5k               1.0     1.0                           0.0                                    0.0
# trained (v3-default) lr=3e-07                      1.0     1.0                           0.5                                    0.0
# trained (v3-default) lr=3e-07 ·min5k               1.0     1.0                           0.5                                    0.0
# untuned (tabicl-v2)                                1.0     1.0                           1.0                                    1.0
# untuned (v2.6-default)                             1.0     1.0                           0.5                                    0.5
# untuned (v3-default)                               1.0     1.0                           1.0                                    1.0
# xgboost                                            0.0     1.0                           0.0                                    0.0
#
#                                               trained (tabicl-v2) lr=1e-06 ·ICLhead ·min5k  trained (tabicl-v2) lr=1e-06 ·min5k  trained (tabicl-v2) lr=3e-07  \
# catboost                                                                               0.0                                  0.0                           0.0
# linreg                                                                                 0.0                                  0.0                           0.0
# trained (tabicl-v2) lr=1e-06                                                           0.5                                  0.5                           0.0
# trained (tabicl-v2) lr=1e-06 ·ICLhead                                                  1.0                                  1.0                           0.0
# trained (tabicl-v2) lr=1e-06 ·ICLhead ·min5k                                           NaN                                  0.5                           0.0
# trained (tabicl-v2) lr=1e-06 ·min5k                                                    0.5                                  NaN                           0.0
# trained (tabicl-v2) lr=3e-07                                                           1.0                                  1.0                           NaN
# trained (tabicl-v2) lr=3e-07 ·ICLhead                                                  1.0                                  1.0                           0.5
# trained (tabicl-v2) lr=3e-07 ·ICLhead ·min5k                                           1.0                                  0.5                           0.0
# trained (tabicl-v2) lr=3e-07 ·min5k                                                    1.0                                  1.0                           0.0
# trained (v2.6-default) lr=1e-06                                                        0.0                                  0.0                           0.0
# trained (v2.6-default) lr=1e-06 ·min5k                                                 0.0                                  0.0                           0.0
# trained (v2.6-default) lr=3e-07                                                        0.0                                  0.0                           0.0
# trained (v2.6-default) lr=3e-07 ·min5k                                                 0.0                                  0.0                           0.0
# trained (v3-default) lr=1e-06                                                          0.0                                  0.0                           0.0
# trained (v3-default) lr=1e-06 ·min5k                                                   0.0                                  0.0                           0.0
# trained (v3-default) lr=3e-07                                                          0.5                                  0.5                           0.0
# trained (v3-default) lr=3e-07 ·min5k                                                   0.5                                  0.0                           0.0
# untuned (tabicl-v2)                                                                    1.0                                  1.0                           0.5
# untuned (v2.6-default)                                                                 1.0                                  0.5                           0.0
# untuned (v3-default)                                                                   1.0                                  1.0                           1.0
# xgboost                                                                                0.0                                  0.0                           0.0
#
#                                               trained (tabicl-v2) lr=3e-07 ·ICLhead  trained (tabicl-v2) lr=3e-07 ·ICLhead ·min5k  \
# catboost                                                                        0.0                                           0.0
# linreg                                                                          0.0                                           0.0
# trained (tabicl-v2) lr=1e-06                                                    0.0                                           0.5
# trained (tabicl-v2) lr=1e-06 ·ICLhead                                           0.0                                           0.5
# trained (tabicl-v2) lr=1e-06 ·ICLhead ·min5k                                    0.0                                           0.0
# trained (tabicl-v2) lr=1e-06 ·min5k                                             0.0                                           0.5
# trained (tabicl-v2) lr=3e-07                                                    0.5                                           1.0
# trained (tabicl-v2) lr=3e-07 ·ICLhead                                           NaN                                           1.0
# trained (tabicl-v2) lr=3e-07 ·ICLhead ·min5k                                    0.0                                           NaN
# trained (tabicl-v2) lr=3e-07 ·min5k                                             0.0                                           0.5
# trained (v2.6-default) lr=1e-06                                                 0.0                                           0.0
# trained (v2.6-default) lr=1e-06 ·min5k                                          0.0                                           0.0
# trained (v2.6-default) lr=3e-07                                                 0.0                                           0.0
# trained (v2.6-default) lr=3e-07 ·min5k                                          0.0                                           0.0
# trained (v3-default) lr=1e-06                                                   0.0                                           0.0
# trained (v3-default) lr=1e-06 ·min5k                                            0.0                                           0.0
# trained (v3-default) lr=3e-07                                                   0.0                                           0.0
# trained (v3-default) lr=3e-07 ·min5k                                            0.0                                           0.0
# untuned (tabicl-v2)                                                             0.5                                           1.0
# untuned (v2.6-default)                                                          0.0                                           0.0
# untuned (v3-default)                                                            1.0                                           1.0
# xgboost                                                                         0.0                                           0.0
#
#                                               trained (tabicl-v2) lr=3e-07 ·min5k  trained (v2.6-default) lr=1e-06  trained (v2.6-default) lr=1e-06 ·min5k  \
# catboost                                                                      0.0                              1.0                                     0.5
# linreg                                                                        0.0                              0.0                                     0.0
# trained (tabicl-v2) lr=1e-06                                                  0.5                              1.0                                     1.0
# trained (tabicl-v2) lr=1e-06 ·ICLhead                                         1.0                              1.0                                     1.0
# trained (tabicl-v2) lr=1e-06 ·ICLhead ·min5k                                  0.0                              1.0                                     1.0
# trained (tabicl-v2) lr=1e-06 ·min5k                                           0.0                              1.0                                     1.0
# trained (tabicl-v2) lr=3e-07                                                  1.0                              1.0                                     1.0
# trained (tabicl-v2) lr=3e-07 ·ICLhead                                         1.0                              1.0                                     1.0
# trained (tabicl-v2) lr=3e-07 ·ICLhead ·min5k                                  0.5                              1.0                                     1.0
# trained (tabicl-v2) lr=3e-07 ·min5k                                           NaN                              1.0                                     1.0
# trained (v2.6-default) lr=1e-06                                               0.0                              NaN                                     0.0
# trained (v2.6-default) lr=1e-06 ·min5k                                        0.0                              1.0                                     NaN
# trained (v2.6-default) lr=3e-07                                               0.0                              1.0                                     0.0
# trained (v2.6-default) lr=3e-07 ·min5k                                        0.0                              1.0                                     1.0
# trained (v3-default) lr=1e-06                                                 0.0                              1.0                                     1.0
# trained (v3-default) lr=1e-06 ·min5k                                          0.0                              1.0                                     1.0
# trained (v3-default) lr=3e-07                                                 0.0                              1.0                                     1.0
# trained (v3-default) lr=3e-07 ·min5k                                          0.0                              1.0                                     1.0
# untuned (tabicl-v2)                                                           1.0                              1.0                                     1.0
# untuned (v2.6-default)                                                        0.5                              1.0                                     1.0
# untuned (v3-default)                                                          1.0                              1.0                                     1.0
# xgboost                                                                       0.0                              1.0                                     0.5
#
#                                               trained (v2.6-default) lr=3e-07  trained (v2.6-default) lr=3e-07 ·min5k  trained (v3-default) lr=1e-06  \
# catboost                                                                  1.0                                     0.5                            0.5
# linreg                                                                    0.0                                     0.0                            0.0
# trained (tabicl-v2) lr=1e-06                                              1.0                                     1.0                            1.0
# trained (tabicl-v2) lr=1e-06 ·ICLhead                                     1.0                                     1.0                            1.0
# trained (tabicl-v2) lr=1e-06 ·ICLhead ·min5k                              1.0                                     1.0                            1.0
# trained (tabicl-v2) lr=1e-06 ·min5k                                       1.0                                     1.0                            1.0
# trained (tabicl-v2) lr=3e-07                                              1.0                                     1.0                            1.0
# trained (tabicl-v2) lr=3e-07 ·ICLhead                                     1.0                                     1.0                            1.0
# trained (tabicl-v2) lr=3e-07 ·ICLhead ·min5k                              1.0                                     1.0                            1.0
# trained (tabicl-v2) lr=3e-07 ·min5k                                       1.0                                     1.0                            1.0
# trained (v2.6-default) lr=1e-06                                           0.0                                     0.0                            0.0
# trained (v2.6-default) lr=1e-06 ·min5k                                    1.0                                     0.0                            0.0
# trained (v2.6-default) lr=3e-07                                           NaN                                     0.0                            0.0
# trained (v2.6-default) lr=3e-07 ·min5k                                    1.0                                     NaN                            0.0
# trained (v3-default) lr=1e-06                                             1.0                                     1.0                            NaN
# trained (v3-default) lr=1e-06 ·min5k                                      1.0                                     1.0                            1.0
# trained (v3-default) lr=3e-07                                             1.0                                     1.0                            1.0
# trained (v3-default) lr=3e-07 ·min5k                                      1.0                                     1.0                            1.0
# untuned (tabicl-v2)                                                       1.0                                     1.0                            1.0
# untuned (v2.6-default)                                                    1.0                                     1.0                            1.0
# untuned (v3-default)                                                      1.0                                     1.0                            1.0
# xgboost                                                                   0.5                                     0.5                            0.5
#
#                                               trained (v3-default) lr=1e-06 ·min5k  trained (v3-default) lr=3e-07  trained (v3-default) lr=3e-07 ·min5k  \
# catboost                                                                       0.0                            0.0                                   0.0
# linreg                                                                         0.0                            0.0                                   0.0
# trained (tabicl-v2) lr=1e-06                                                   1.0                            0.5                                   0.5
# trained (tabicl-v2) lr=1e-06 ·ICLhead                                          1.0                            1.0                                   1.0
# trained (tabicl-v2) lr=1e-06 ·ICLhead ·min5k                                   1.0                            0.5                                   0.5
# trained (tabicl-v2) lr=1e-06 ·min5k                                            1.0                            0.5                                   1.0
# trained (tabicl-v2) lr=3e-07                                                   1.0                            1.0                                   1.0
# trained (tabicl-v2) lr=3e-07 ·ICLhead                                          1.0                            1.0                                   1.0
# trained (tabicl-v2) lr=3e-07 ·ICLhead ·min5k                                   1.0                            1.0                                   1.0
# trained (tabicl-v2) lr=3e-07 ·min5k                                            1.0                            1.0                                   1.0
# trained (v2.6-default) lr=1e-06                                                0.0                            0.0                                   0.0
# trained (v2.6-default) lr=1e-06 ·min5k                                         0.0                            0.0                                   0.0
# trained (v2.6-default) lr=3e-07                                                0.0                            0.0                                   0.0
# trained (v2.6-default) lr=3e-07 ·min5k                                         0.0                            0.0                                   0.0
# trained (v3-default) lr=1e-06                                                  0.0                            0.0                                   0.0
# trained (v3-default) lr=1e-06 ·min5k                                           NaN                            0.5                                   0.0
# trained (v3-default) lr=3e-07                                                  0.5                            NaN                                   0.5
# trained (v3-default) lr=3e-07 ·min5k                                           1.0                            0.5                                   NaN
# untuned (tabicl-v2)                                                            1.0                            1.0                                   1.0
# untuned (v2.6-default)                                                         1.0                            1.0                                   0.5
# untuned (v3-default)                                                           1.0                            1.0                                   1.0
# xgboost                                                                        0.0                            0.0                                   0.0
#
#                                               untuned (tabicl-v2)  untuned (v2.6-default)  untuned (v3-default)  xgboost
# catboost                                                      0.0                     0.0                   0.0      1.0
# linreg                                                        0.0                     0.0                   0.0      0.0
# trained (tabicl-v2) lr=1e-06                                  0.0                     0.5                   0.0      1.0
# trained (tabicl-v2) lr=1e-06 ·ICLhead                         0.0                     0.5                   0.0      1.0
# trained (tabicl-v2) lr=1e-06 ·ICLhead ·min5k                  0.0                     0.0                   0.0      1.0
# trained (tabicl-v2) lr=1e-06 ·min5k                           0.0                     0.5                   0.0      1.0
# trained (tabicl-v2) lr=3e-07                                  0.5                     1.0                   0.0      1.0
# trained (tabicl-v2) lr=3e-07 ·ICLhead                         0.5                     1.0                   0.0      1.0
# trained (tabicl-v2) lr=3e-07 ·ICLhead ·min5k                  0.0                     1.0                   0.0      1.0
# trained (tabicl-v2) lr=3e-07 ·min5k                           0.0                     0.5                   0.0      1.0
# trained (v2.6-default) lr=1e-06                               0.0                     0.0                   0.0      0.0
# trained (v2.6-default) lr=1e-06 ·min5k                        0.0                     0.0                   0.0      0.5
# trained (v2.6-default) lr=3e-07                               0.0                     0.0                   0.0      0.5
# trained (v2.6-default) lr=3e-07 ·min5k                        0.0                     0.0                   0.0      0.5
# trained (v3-default) lr=1e-06                                 0.0                     0.0                   0.0      0.5
# trained (v3-default) lr=1e-06 ·min5k                          0.0                     0.0                   0.0      1.0
# trained (v3-default) lr=3e-07                                 0.0                     0.0                   0.0      1.0
# trained (v3-default) lr=3e-07 ·min5k                          0.0                     0.5                   0.0      1.0
# untuned (tabicl-v2)                                           NaN                     1.0                   0.0      1.0
# untuned (v2.6-default)                                        0.0                     NaN                   0.0      1.0
# untuned (v3-default)                                          1.0                     1.0                   NaN      1.0
# xgboost                                                       0.0                     0.0                   0.0      NaN

# %%
sink.save(plot_winrate_matrix(TRACK), 'winrate_matrix',
          caption="Pairwise win rate: the fraction of shared (dataset, fold) cells on which the row method beat the column method.")

# %%
# Pick any two methods from `available_methods(TRACK)`. The defaults
# below compare XGBoost (the strongest classical) against the best
# trained CreditPFN (whichever currently leads the leaderboard).
methods = available_methods(TRACK)
if len(methods) >= 2:
    classical_pick = next((m for m in methods if m == 'xgboost'), methods[0])
    creditpfn_pick = next((m for m in eval_leaderboard(TRACK)['method_name'].tolist()
                           if m.startswith('trained (')), methods[-1])
    _ = plot_method_vs_method_scatter(TRACK, classical_pick, creditpfn_pick)
else:
    print('Need at least two methods on disk to draw a scatter.')

# %% [markdown]
# ## 5 · Trained vs untuned TabPFN
#
# The **Real-TabPFN** [Garg 2025](../tfm-library/papers/2025/07_Garg_et_al._Real_TabPFN_Improving_Tabular_Foundation_Models_via_Continued_Pre_training_With_Real_World_Data.pdf)
# headline figure: for each `(test_dataset, trained_checkpoint)`,
# scatter the trained metric against the matching untuned TabPFN
# of the **same architecture**. Points above the y = x line are
# datasets where continued pretraining actually helped.
#
# Points are coloured by base architecture — so you can spot
# *"v3 helps but v2.5 doesn't"* or vice versa.

# %%
sink.save(plot_trained_vs_untuned(TRACK), 'trained_vs_untuned',
          caption="Primary metric of each trained checkpoint against its own untuned base on the same dataset. Points above the diagonal are datasets where continued pretraining helped.")

# %% [markdown]
# ## 6 · Stability and calibration
#
# * **Fold stability** — std of the primary metric across the 5
#   outer folds for each `(method, dataset)`. A method whose box
#   sits high is reporting high variance — a worse choice for
#   production even if its mean looks good.
# * **Metric correlation** — pairwise correlation between every
#   metric column on disk. Useful to know whether picking the
#   ROC-AUC winner is robust to switching to PR-AUC, or whether
#   there's a calibration / discrimination trade-off lurking.
# * **Threshold distribution** *(PD only)* — F1-optimal threshold
#   per method. A method whose threshold drifts far from 0.5
#   produces poorly-calibrated probabilities.

# %%
sink.save(plot_fold_stability(TRACK), 'fold_stability',
          caption="Distribution of the across-fold standard deviation of the primary metric, per method — how repeatable a score is.")

# %%
sink.save(plot_metric_correlation(TRACK), 'metric_correlation',
          caption="Correlation between the recorded metrics over all scored cells.")

# %%
sink.save(plot_threshold_distribution(TRACK), 'threshold_distribution',
          caption="Distribution of the F1-tuned decision thresholds per method, over all (dataset, fold) cells.")

# %% [markdown]
# ## 7 · Time vs accuracy
#
# Per-fold elapsed seconds against the primary metric. Pareto-dominated
# points are methods that another method matches in less time.

# %%
sink.save(plot_time_vs_metric(TRACK), 'time_vs_metric',
          caption="Per-row inference time against primary metric, one point per (method, dataset), coloured by method.")

# %% [markdown]
# ## 8 · Failures
#
# Any `(method, dataset, fold)` triple with status ≠ OK. Most often
# an HPO timeout (Optuna budget exhausted) or a CUDA OOM on a wide
# dataset. Investigate the `error` column before treating an empty
# row in the heatmap as missing data.

# %%
fails = failed_pairs(TRACK)
if fails.empty:
    print('No failed (method × dataset × fold) rows. ✔')
else:
    display(fails)
# Out:
# No failed (method × dataset × fold) rows. ✔

# %% [markdown]
# ## 9. Figures for the paper
#
# The set below is what a manuscript about this project needs, and is kept deliberately
# small; everything above this point is diagnostic. Each one answers a question the
# literature says a continued-pretraining result must answer:
#
# | figure | question | precedent |
# |---|---|---|
# | paired effect | did continued pretraining help, against each model's **own** base? | every CPT paper |
# | gain vs base quality | does it help most where the base was weakest? | our mechanism |
# | mean rank | which model wins across datasets, scale-free? | Hollmann 2025, Purucker 2026 |
# | calibration shift | did adaptation damage the probabilities? | Tanna 2026; regulatory relevance |
# | regime | where does it help — as a function of dataset size? | Purucker 2026 (ρ = +0.60) |
# | honest selection | how much does best-on-test overstate? | winner's curse |
# | forgetting | did adaptation destroy what the prior knew? | Kolberg 2026 (ρ = 0.9935) |
#
# All of them are **paired**: a trained checkpoint is compared to its own untuned base on
# the same dataset. An unpaired mean over models scored on different dataset subsets is
# dominated by which datasets each model happened to get — which is exactly what a partial
# eval produces.

# %%
from src.visualize import paper_figures as pf
from src.utils.paths import manifests_dir

METRIC = primary_metric(TRACK)
# Dataset properties for the regime figure: rows, features, imbalance.
corpus_manifest = pd.read_csv(manifests_dir() / f'manifest_{TRACK}.csv')
print(f'paper figures: metric={METRIC}, {len(corpus_manifest)} datasets in the manifest')
# Out:
# paper figures: metric=rmse, 8 datasets in the manifest

# %%
sink.save(pf.plot_paired_delta(raw, METRIC), 'paper_paired_effect',
          caption="Change in rmse from continued pretraining, each trained checkpoint against its own untuned base on the same dataset. One point per (checkpoint, dataset); horizontal bars mark the per-base mean; the line at zero is no change.")

# %%
sink.save(pf.plot_gain_vs_base(raw, METRIC), 'paper_gain_vs_base',
          caption="Change in rmse against the untuned base's score on the same dataset, one point per (checkpoint, dataset), coloured by base checkpoint. The line is an ordinary least-squares fit over all points.")

# %%
sink.save(pf.plot_mean_rank(raw, METRIC, label_map=None),
          'paper_mean_rank',
          caption="Mean rank of each method across the held-out datasets scored by every method, computed per dataset and then averaged; bars show one standard deviation. Rank 1 is best.")

# %%
sink.save(pf.plot_calibration_shift(raw), 'paper_calibration',
          caption="Expected calibration error of each trained checkpoint against its own untuned base on the same dataset. Points above the diagonal are worse calibrated after continued pretraining.")

# %%
sink.save(pf.plot_regime_effect(raw, corpus_manifest, METRIC, 'n_rows'), 'paper_regime',
          caption="Change in rmse against dataset size, one point per (checkpoint, dataset), log x axis. Spearman correlation and its p-value are computed over all points shown.")

# %%
sink.save(pf.plot_selection_honesty(raw, METRIC), 'paper_selection',
          caption="Per dataset, the rmse of the configuration selected on the other datasets only (leave-one-dataset-out) against the best rmse achievable on that dataset. The gap is the optimism of selecting on the test set.")

# %%
sink.save(pf.plot_forgetting(raw, METRIC), 'paper_forgetting',
          caption="Trained against untuned rmse for every (checkpoint, dataset) pair, with the identity line. Spearman correlation over all pairs quantifies how far adaptation reordered the model's behaviour.")

# %% [markdown]
# ## 9 · What the run actually shows
#
# Three figures that carry the argument and are not derivable from the
# leaderboard: the zero-shot comparison against tuned baselines, the corpus
# arm, and the effect size with a confidence interval over datasets.

# %%
sink.save(pf.plot_zero_shot_vs_baseline(raw, METRIC), 'paper_zero_shot',
          caption='Difference in RMSE between each untuned tabular foundation model and the best of three hyperparameter-tuned classical baselines (XGBoost, CatBoost, ridge regression; 50 Optuna trials each) on the same held-out dataset, signed so that bars above zero favour the foundation model. Grouped by dataset; one bar per base checkpoint.')

# %%
sink.save(pf.plot_corpus_arm(raw, METRIC), 'paper_corpus_arm',
          caption='Mean change in RMSE from continued pretraining, per base checkpoint, split by the minimum training-table size admitted to the corpus, signed so that positive is an improvement. Error bars are one standard error over (checkpoint, dataset) pairs.')

# %%
sink.save(pf.plot_effect_ci(raw, METRIC), 'paper_effect_ci',
          caption='Mean change in RMSE from continued pretraining with a 95 % confidence interval, computed over held-out datasets after averaging within each dataset and signed so that positive is an improvement. An interval spanning zero indicates no effect detectable at this sample size.')

# %% [markdown]
# ## 10 · The scheme benchmark
#
# The comparison this project is actually about. Not TabPFN against TabICLv2 —
# those differ in architecture and pretraining data, so ranking them measures the
# vendors. What varies here is the **adaptation scheme** (learning rate, adapter vs
# full fine-tune, corpus filter), and every scheme is scored against the base
# checkpoint it started from, per dataset and across metrics.

# %%
sink.save(pf.plot_scheme_grid(raw, METRIC), 'paper_scheme_grid',
          caption="Change in RMSE from continued pretraining for every adaptation scheme (rows) on every held-out dataset (columns), one panel per base checkpoint, each measured against that base's own untuned score on the same dataset and signed so that red is an improvement. The colour scale is shared across panels.")

# %%
sink.save(pf.plot_scheme_metrics(raw, ('rmse', 'r2')), 'paper_scheme_metrics',
          caption='Mean change from continued pretraining per adaptation scheme, one panel per base checkpoint, for RMSE and R-squared, signed so that positive favours the adapted model and averaged over the held-out datasets.')

# %% [markdown]
# ## Summary
#
# Everything above, as text. This is the block `src/utils/run_notebooks.py`
# collects into `output/All_Results.md`, so it has to stand on its own: section
# order follows this notebook's, and every figure's headline number is restated
# here rather than living only inside a PDF.

# %%
from src.visualize import summaries

fails = failed_pairs(TRACK)
print(summaries.eval_summary(TRACK))
print()
print(f'failed (method x dataset x fold) rows: {len(fails)}')
if len(fails):
    print(fails.to_string())
print()
print(sink.summary())
# Out:
# ==========================================================================
#   2.1. LGD FINAL RESULTS
# ==========================================================================
#   held-out benchmark · primary metric = rmse
#
#
# 1. Coverage
# -----------
#   methods scored     : 22
#   held-out datasets  : 2
#   (method,ds,fold)   : 220 OK, 0 FAIL
#   complete grid      : yes
#
# 2. Leaderboard (mean over datasets x folds)
# -------------------------------------------
#   untuned (v3-default)                           0.1326
#   untuned (tabicl-v2)                            0.1337
#   trained (tabicl-v2) lr=3e-07 ·ICLhead          0.1339
#   trained (tabicl-v2) lr=3e-07                   0.1339
#   trained (tabicl-v2) lr=1e-06 ·ICLhead          0.1342
#   ... 16 more ...
#   linreg                                         0.1983   (last)
#
# 3. Zero-shot foundation model vs best tuned baseline
# ----------------------------------------------------
#   untuned tabicl-v2        wins 2/2   mean delta +0.0070
#   untuned v2.6-default     wins 2/2   mean delta +0.0066
#   untuned v3-default       wins 2/2   mean delta +0.0082
#   overall                  6/6 pairs above zero
#
# 4. Effect of continued pretraining (paired vs own base)
# -------------------------------------------------------
#   overall            2/32 wins   mean -0.0040   median -0.0013   best +0.0001
#     tabicl-v2        2/16   mean -0.0005
#     v2.6-default     0/8   mean -0.0116
#     v3-default       0/8   mean -0.0036
#   per-dataset mean   n=2   mean -0.0040
#   95% CI over datasets: [-0.0129, +0.0048]   p = 0.109   -> no detectable effect
#
# 5. Corpus-size arm (min_train_rows)
# -----------------------------------
#   min5000    n= 16  mean -0.0032  wins 0/16
#   none       n= 16  mean -0.0049  wins 2/16
#
# 6. Calibration (PD only)
# ------------------------
#   no ECE recorded (regression track)
#
# 7. Mean rank across datasets scored by every method
# ---------------------------------------------------
#   untuned (v3-default)                           1.00
#   trained (tabicl-v2) lr=3e-07                   3.00
#   untuned (tabicl-v2)                            3.00
#
# 8. Regime and honesty checks
# ----------------------------
#   best dataset  : 0007.lgd_lendingclub  -0.0033
#   worst dataset : 0002.loss2  -0.0047
#   forgetting (Spearman trained vs untuned over pairs): 0.8484
#   gain vs base quality (r over pairs): -0.15   [32 pairs on 2 datasets]
#
# 9. Best method on each held-out dataset
# ---------------------------------------
#   0002.loss2                   0.1399  untuned (v3-default)
#   0007.lgd_lendingclub         0.1253  untuned (v3-default)
#
# 10. Fold stability (std across the 5 folds, median over datasets)
# -----------------------------------------------------------------
#
# 11. Failures
# ------------
#   none — every (method, dataset, fold) cell produced a number
#
# 12. Reading it
# --------------
#   Continued pretraining did not help on average (-0.0040 rmse).
#   Untuned foundation models beat the best tuned baseline on 6/6 (base, dataset) pairs.
#   Every number above rests on 2 held-out datasets — too few for significance.
#
# failed (method x dataset x fold) rows: 0
#
# 2.1. final_results_lgd: 24 figures -> output/figures/2.1. final_results_lgd
#   01  leaderboard
#   02  metric_boxplot
#   03  baselines_vs_tabpfn
#   04  per_dataset_heatmap
#   05  top_method_per_dataset
#   06  dataset_difficulty
#   07  winrate_matrix
#   08  trained_vs_untuned
#   09  fold_stability
#   10  metric_correlation
#   11  threshold_distribution
#   12  time_vs_metric
#   13  paper_paired_effect
#   14  paper_gain_vs_base
#   15  paper_mean_rank
#   16  paper_calibration
#   17  paper_regime
#   18  paper_selection
#   19  paper_forgetting
#   20  paper_zero_shot
#   21  paper_corpus_arm
#   22  paper_effect_ci
#   23  paper_scheme_grid
#   24  paper_scheme_metrics
